# %%
import pandas as pd
data = pd.read_csv('운동처방결과데이터.csv')
data
# Out:
#     Unnamed: 0  Unnamed: 0.1                 name  \
# 0            0             0       저항밴드 운동 루틴프로그램
# 1            1             1      웨이트 트레이닝 루틴프로그램
# 2            2             2          맨몸운동 루틴프로그램
# 3            3             3     앉았다 일어서며 팔 들어올리기
# 4            4             4          런지하며 상체 비틀기
# 5            5             5          팔 들어 올리며 런지
# 6            6             6         한 발 뒤로 들어올리기
# 7            7             7             다리 감아올리기
# 8            8             8             상체 감아올리기
# 9            9             9       발에 밴드걸고 윗몸일으키기
# 10          10            10              옆으로 굽히기
# 11          11            11            한 발 끌어당기기
# 12          12            12            한 발 들어올리기
# 13          13            13           앉아서 무릎 굽히기
# 14          14            14           앉아서 다리 올리기
# 15          15            15              뒤로 팔 뻗기
# 16          16            16            양팔 크게 벌리기
# 17          17            17         팔꿈치 고정 후 벌리기
# ...
