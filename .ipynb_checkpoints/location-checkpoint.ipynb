# %%
import pandas as pd
data = pd.read_csv("운동처방데이터저장.csv")
data
# Out:
#                  name                                          site_link 운동대상  \
# 0     웨이트 트레이닝 루틴프로그램  /entry.naver?docId=3535306&categoryId=58501&ci...  청소년
# 1         맨몸운동 루틴프로그램  /entry.naver?docId=3535307&categoryId=58501&ci...  청소년
# 2    앉았다 일어서며 팔 들어올리기  /entry.naver?docId=3535308&categoryId=58501&ci...  청소년
# 3         런지하며 상체 비틀기  /entry.naver?docId=3535309&categoryId=58501&ci...  청소년
# 4         팔 들어 올리며 런지  /entry.naver?docId=3535310&categoryId=58501&ci...  청소년
# ..                ...                                                ...  ...
# 491            풍선 튕기기  /entry.naver?docId=3535807&categoryId=58501&ci...  어르신
# 492       머리 위로 공 넘기기  /entry.naver?docId=3535808&categoryId=58501&ci...  어르신
# 493            발바닥 치기  /entry.naver?docId=3535809&categoryId=58501&ci...  어르신
# 494           앞뒤로 선넘기  /entry.naver?docId=3535810&categoryId=58501&ci...  어르신
# 495           좌우로 선넘기  /entry.naver?docId=3535811&categoryId=58501&ci...  어르신
#
#         체력항목   운동형태             운동부위 시설 필요유무
# 0    근력/근지구력  웨이트기계      전신/가슴/상체/하체       Y
# 1    근력/근지구력     맨몸      전신/가슴/상체/하체       N
# 2    근력/근지구력     밴드       어깨측면/허벅지앞쪽       Y
# 3    근력/근지구력     밴드       어깨측면/허벅지앞쪽       Y
# 4    근력/근지구력     밴드  어깨뒤쪽/어깨측면/허벅지앞쪽       Y
# ..       ...    ...              ...     ...
# 491      협응력     풍선               전신       Y
# 492      협응력      공               전신       Y
# 493      협응력     맨몸               전신       N
# 494      협응력     맨몸               전신       N
# 495      협응력     맨몸               전신       N
#
# [496 rows x 7 columns]

# %%
import numpy as np
import pandas as pd
import urllib
from urllib.request import urlopen
from urllib import parse
from urllib.request import Request
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json

# %%
address="서울특별시 중구 필동로1길 30(필동3가)"

# %%
#naver map api key
client_id = '7mfj21mpta';    # 본인이 할당받은 ID 입력
client_pw = 'pdtBr9oxlKR3PS6WViF1vDykk4uSSFStHJt2xS0v';    # 본인이 할당받은 Secret 입력

api_url = 'https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query='

# 주소 목록 파일 (.csv)
# data = pd.read_csv('파일명.csv')
# 주소 목록 파일 (.xlsx)
# data = pd.read_excel('파일명.xlsx')

# 네이버 지도 API 이용해서 위경도 찾기
print(address)
add_urlenc = parse.quote(address)  
url = api_url + add_urlenc
request = Request(url)
request.add_header('X-NCP-APIGW-API-KEY-ID', client_id)
request.add_header('X-NCP-APIGW-API-KEY', client_pw)

try:
    response = urlopen(request)
except HTTPError as e:
    print('HTTP Error!')
    latitude = None
    longitude = None
else:
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read().decode('utf-8')
        response_body = json.loads(response_body)   # json
        if response_body['addresses'] == [] :
            print("'result' not exist!")
            latitude = None
            longitude = None
        else:
            latitude = response_body['addresses'][0]['y']
            longitude = response_body['addresses'][0]['x']
            print("위도: ", latitude, "경도: ", longitude)
            print("Success!")
    else:
        print('Response error code : %d' % rescode)
        latitude = None
        longitude = None
# Out:
# 서울특별시 중구 필동로1길 30(필동3가)
# 위도:  37.5582582 경도:  127.0001869
# Success!

# %%
list_add = list(address.split())
print(list_add)
print(list_add[0],list_add[1])
si = list_add[0]
gu =list_add[1]
# Out:
# ['서울특별시', '중구', '필동로1길', '30(필동3가)']
# 서울특별시 중구

# %%
data2 = pd.read_csv("전국체육시설현황데이터.csv")
data2

data2=data2.fillna(0)
data2
# is_target=bmi['COAW_FLAG_NM'] == person1.target
# target=bmi[is_target]
# Out:
#                    FACI_NM FACI_GB_CD FACI_GB_NM FCOB_CD FCOB_NM FTYPE_CD  \
# 0                  (외립석입구)          P         공공     P08   간이운동장    P0801
# 1          (주)한샘레포츠타운(공단점)          N         신고     N10  체력단련장업    N1001
# 2                  (자산경로당)          P         공공     P08   간이운동장    P0801
# 3               볼&큐 빌리어드클럽          N         신고     N11    당구장업    N1101
# 4                안산 힘찬 태권도          N         신고     N08   체육도장업    N0805
# ...                    ...        ...        ...     ...     ...      ...
# 108282  美 Diet Boxing Club          N         신고     N08   체육도장업    N0801
# 108283   우리 아이풀(舊 크레피아수영장)          N         신고     N07    수영장업    N0701
# 108284               身휘트니스          N         신고     N10  체력단련장업    N1001
# 108285            태권道장 휘영찬          N         신고     N08   체육도장업    N0805
# 108286             道心성인태권도          N         신고     N08   체육도장업    N0805
#
#        FTYPE_NM FACI_STAT  FACI_ROAD_POST  \
# 0         간이운동장      정상운영             0.0
# 1         체력단련장      정상운영         15433.0
# 2         간이운동장      정상운영         39588.0
# 3           당구장      정상운영        426811.0
# 4           태권도      정상운영         15535.0
# ...         ...       ...             ...
# 108282       권투      정상운영          7262.0
# 108283       실내      정상운영        302800.0
# 108284    체력단련장      정상운영        463827.0
# 108285      태권도      정상운영        302812.0
# 108286      태권도      정상운영          1384.0
#
#                                   FACI_ROAD_ADDR1  ...    CP_YMD    TH_YMD  \
# 0                                               0  ...
# 1                        경기도 안산시 단원구 동산로 63 (원시동)  ...
# 2                          경상북도 김천시 자산3길 16 (성내동)  ...
# 3                    경기도 안산시 상록구 반석로 88, 4층 (본오동)  ...
# 4                       경기도 안산시 상록구 각골로 127 (본오동)  ...
# ...                                           ...  ...       ...       ...
# 108282               서울특별시 영등포구 영등포로 85-1 (양평동1가)  ...
# 108283                   대전광역시 서구 계백로 1186 (가수원동)  ...
# 108284  경기도 성남시 분당구 성남대로 912, 지하1층 (야탑동, 분당BYC빌딩)  ...
# 108285                 대전광역시 서구 관저동로 66 (관저동, 3층)  ...
# 108286                     서울특별시 도봉구 방학로 175(방학동)  ...
#
#         SDWN_YMD NATION_YN  SSM_DSN_YN  ATNM_CHK_YN DATA_FROM_GB_CD DEL_YN  \
# 0                        N                        N               0      N
# 1                        N                        Y               0      N
# 2                        N                        N            SFMS      N
# 3                        N                        Y             태블릿      N
# 4                        N                        Y            SFMS      N
# ...          ...       ...         ...          ...             ...    ...
# 108282                   N                        Y             태블릿      N
# 108283                   N           N            N               0      N
# 108284                   N                        Y             태블릿      N
# 108285                   N                        Y               0      N
# 108286                   N                        Y            SFMS      N
#
#             REG_DT      UPD_DT
# 0       2020-02-10  2020-02-10
# 1       2016-12-31  2017-02-26
# 2       2020-02-10  2021-04-29
# 3       2016-12-31  2019-01-14
# 4       2016-12-31  2019-03-13
# ...            ...         ...
# 108282  2016-12-30  2019-01-03
# 108283  2016-12-31  2018-09-19
# 108284  2016-12-31  2020-07-27
# 108285  2016-12-31  2018-09-20
# 108286  2021-09-01  2021-09-01
#
# [108287 rows x 58 columns]

# %%
#!pip install scipy

# %%
data3 = data2[['FACI_STAT','CP_NM','CPB_NM','FACI_POINT_X','FACI_POINT_Y','FMNG_USER_TEL','FACI_ROAD_ADDR1','FACI_ADDR1']]
data3

from scipy.spatial import distance
#round(distance.euclidean((경도,위도 ), (longitude, latitude)),5)

x_list=data3['FACI_POINT_X'].tolist()
y_list = data3['FACI_POINT_Y'].tolist()
list_dis=[]

#print(x_list,y_list)

for i in range(0,len(x_list)):
    #print(round(distance.euclidean((float(longitude),float(latitude)), (x_list[i], y_list[i])),5))
    list_dis.append(round(distance.euclidean((float(longitude),float(latitude)), (x_list[i], y_list[i])),5))

data3["거리"]=pd.DataFrame(list_dis)
data3
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15032/1928125692.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["거리"]=pd.DataFrame(list_dis)
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 0           정상운영   경상북도    김천시      0.000000      0.000000  054-420-8033
# 1           정상운영    경기도    안산시    126.797270     37.314431  031-492-3391
# 2           정상운영   경상북도    김천시    128.122092     36.120771  054-420-8077
# 3           정상운영    경기도    안산시    126.869468     37.296411             0
# 4           정상운영    경기도    안산시    126.872700     37.300895             0
# ...          ...    ...    ...           ...           ...           ...
# 108282      정상운영  서울특별시   영등포구    126.891175     37.522315             0
# 108283      정상운영  대전광역시     서구    127.355226     36.304872  042-541-7944
# 108284      정상운영    경기도    성남시    127.129262     37.410966             0
# 108285      정상운영  대전광역시     서구    127.340994     36.298068  042-542-9091
# 108286      정상운영  서울특별시    도봉구    127.032648     37.662070             0
#
#                                   FACI_ROAD_ADDR1               FACI_ADDR1  \
# 0                                               0             경상북도 예지리 680
# 1                        경기도 안산시 단원구 동산로 63 (원시동)                        0
# 2                          경상북도 김천시 자산3길 16 (성내동)      경상북도 김천시 성내동 161-17
# 3                    경기도 안산시 상록구 반석로 88, 4층 (본오동)                        0
# 4                       경기도 안산시 상록구 각골로 127 (본오동)  경기도 안산시 상록구 본오동 1118-10
# ...                                           ...                      ...
# 108282               서울특별시 영등포구 영등포로 85-1 (양평동1가)   서울특별시 영등포구 양평동1가  28-3
# 108283                   대전광역시 서구 계백로 1186 (가수원동)                        0
# 108284  경기도 성남시 분당구 성남대로 912, 지하1층 (야탑동, 분당BYC빌딩)      경기 성남시 분당구 성남대로 912
# 108285                 대전광역시 서구 관저동로 66 (관저동, 3층)            대전 서구 관저동로 66
# 108286                     서울특별시 도봉구 방학로 175(방학동)      서울특별시 도봉구 방학동 669-2
#
#                거리
# 0       132.43742
# 1         0.31722
# 2         1.82347
# 3         0.29266
# 4         0.28721
# ...           ...
# 108282    0.11478
# 108283    1.30270
# 108284    0.19585
# 108285    1.30546
# 108286    0.10877
#
# [108287 rows x 9 columns]

# %%
import numpy as np
data3=data3.replace(0,np.nan)
data3
# Out:
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 0           정상운영   경상북도    김천시           NaN           NaN  054-420-8033
# 1           정상운영    경기도    안산시    126.797270     37.314431  031-492-3391
# 2           정상운영   경상북도    김천시    128.122092     36.120771  054-420-8077
# 3           정상운영    경기도    안산시    126.869468     37.296411           NaN
# 4           정상운영    경기도    안산시    126.872700     37.300895           NaN
# ...          ...    ...    ...           ...           ...           ...
# 108282      정상운영  서울특별시   영등포구    126.891175     37.522315           NaN
# 108283      정상운영  대전광역시     서구    127.355226     36.304872  042-541-7944
# 108284      정상운영    경기도    성남시    127.129262     37.410966           NaN
# 108285      정상운영  대전광역시     서구    127.340994     36.298068  042-542-9091
# 108286      정상운영  서울특별시    도봉구    127.032648     37.662070           NaN
#
#                                   FACI_ROAD_ADDR1               FACI_ADDR1  \
# 0                                             NaN             경상북도 예지리 680
# 1                        경기도 안산시 단원구 동산로 63 (원시동)                      NaN
# 2                          경상북도 김천시 자산3길 16 (성내동)      경상북도 김천시 성내동 161-17
# 3                    경기도 안산시 상록구 반석로 88, 4층 (본오동)                      NaN
# 4                       경기도 안산시 상록구 각골로 127 (본오동)  경기도 안산시 상록구 본오동 1118-10
# ...                                           ...                      ...
# 108282               서울특별시 영등포구 영등포로 85-1 (양평동1가)   서울특별시 영등포구 양평동1가  28-3
# 108283                   대전광역시 서구 계백로 1186 (가수원동)                      NaN
# 108284  경기도 성남시 분당구 성남대로 912, 지하1층 (야탑동, 분당BYC빌딩)      경기 성남시 분당구 성남대로 912
# 108285                 대전광역시 서구 관저동로 66 (관저동, 3층)            대전 서구 관저동로 66
# 108286                     서울특별시 도봉구 방학로 175(방학동)      서울특별시 도봉구 방학동 669-2
#
#                거리
# 0       132.43742
# 1         0.31722
# 2         1.82347
# 3         0.29266
# 4         0.28721
# ...           ...
# 108282    0.11478
# 108283    1.30270
# 108284    0.19585
# 108285    1.30546
# 108286    0.10877
#
# [108287 rows x 9 columns]

# %%
condition=(data3.FACI_STAT == '정상운영')
data3[condition]
# Out:
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 0           정상운영   경상북도    김천시           NaN           NaN  054-420-8033
# 1           정상운영    경기도    안산시    126.797270     37.314431  031-492-3391
# 2           정상운영   경상북도    김천시    128.122092     36.120771  054-420-8077
# 3           정상운영    경기도    안산시    126.869468     37.296411           NaN
# 4           정상운영    경기도    안산시    126.872700     37.300895           NaN
# ...          ...    ...    ...           ...           ...           ...
# 108282      정상운영  서울특별시   영등포구    126.891175     37.522315           NaN
# 108283      정상운영  대전광역시     서구    127.355226     36.304872  042-541-7944
# 108284      정상운영    경기도    성남시    127.129262     37.410966           NaN
# 108285      정상운영  대전광역시     서구    127.340994     36.298068  042-542-9091
# 108286      정상운영  서울특별시    도봉구    127.032648     37.662070           NaN
#
#                                   FACI_ROAD_ADDR1               FACI_ADDR1  \
# 0                                             NaN             경상북도 예지리 680
# 1                        경기도 안산시 단원구 동산로 63 (원시동)                      NaN
# 2                          경상북도 김천시 자산3길 16 (성내동)      경상북도 김천시 성내동 161-17
# 3                    경기도 안산시 상록구 반석로 88, 4층 (본오동)                      NaN
# 4                       경기도 안산시 상록구 각골로 127 (본오동)  경기도 안산시 상록구 본오동 1118-10
# ...                                           ...                      ...
# 108282               서울특별시 영등포구 영등포로 85-1 (양평동1가)   서울특별시 영등포구 양평동1가  28-3
# 108283                   대전광역시 서구 계백로 1186 (가수원동)                      NaN
# 108284  경기도 성남시 분당구 성남대로 912, 지하1층 (야탑동, 분당BYC빌딩)      경기 성남시 분당구 성남대로 912
# 108285                 대전광역시 서구 관저동로 66 (관저동, 3층)            대전 서구 관저동로 66
# 108286                     서울특별시 도봉구 방학로 175(방학동)      서울특별시 도봉구 방학동 669-2
#
#                거리
# 0       132.43742
# 1         0.31722
# 2         1.82347
# 3         0.29266
# 4         0.28721
# ...           ...
# 108282    0.11478
# 108283    1.30270
# 108284    0.19585
# 108285    1.30546
# 108286    0.10877
#
# [88134 rows x 9 columns]

# %%
# is_target=bmi['COAW_FLAG_NM'] == person1.target
# target=bmi[is_target]

same_si = data3['CP_NM']==si
target = data3[same_si]
target
# Out:
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 252         정상운영  서울특별시   영등포구    126.891347     37.525494           NaN
# 253         정상운영  서울특별시    강동구    127.129657     37.556670           NaN
# 261         정상운영  서울특별시    구로구    126.870255     37.504717           NaN
# 262         정상운영  서울특별시    송파구    127.125738     37.497661   02-565-9015
# 265         정상운영  서울특별시    종로구    127.016000     37.574056           NaN
# ...          ...    ...    ...           ...           ...           ...
# 108269        폐업  서울특별시    관악구    126.913418     37.480527           NaN
# 108274      정상운영  서울특별시     중구    126.994825     37.561141           NaN
# 108278      정상운영  서울특별시   영등포구    126.897059     37.534560           NaN
# 108282      정상운영  서울특별시   영등포구    126.891175     37.522315           NaN
# 108286      정상운영  서울특별시    도봉구    127.032648     37.662070           NaN
#
#                           FACI_ROAD_ADDR1                        FACI_ADDR1  \
# 252            서울특별시 영등포구 선유로 130 (양평동3가)  서울특별시 영등포구 양평동3가 5-4 에이스 하이테크시티3
# 253              서울특별시 강동구 올림픽로 847 (암사동)      서울특별시 강동구 암사동 190-23 에이든1215
# 261           서울특별시 구로구 안양천로539길 11 (고척동)      서울특별시 구로구 고척동 60-34 제니스스포츠클럽
# 262     서울특별시 송파구 중대로 174 (가락동, 가락동 주상복합)      서울특별시 송파구 가락동 147-2 가락동 주상복합
# 265      서울특별시 종로구 종로 347 (숭인동, 롯데캐슬 천지인)         서울특별시 종로구 숭인동 76 롯데캐슬 천지인
# ...                                   ...                               ...
# 108269          서울특별시 관악구 난곡로61길 12 (신림동)              서울특별시 관악구 신림동 1483-8
# 108274                    서울 중구 필동2가 15-7                   서울 중구 필동2가 15-7
# 108278         서울특별시 영등포구 선유로 246 (양평동4가)                   서울 영등포구 선유로 246
# 108282       서울특별시 영등포구 영등포로 85-1 (양평동1가)            서울특별시 영등포구 양평동1가  28-3
# 108286             서울특별시 도봉구 방학로 175(방학동)               서울특별시 도봉구 방학동 669-2
#
#              거리
# 252     0.11366
# 253     0.12948
# 261     0.14053
# 262     0.13941
# 265     0.02235
# ...         ...
# 108269  0.11649
# 108274  0.00609
# 108278  0.10582
# 108282  0.11478
# 108286  0.10877
#
# [16433 rows x 9 columns]

# %%
same_gu = target['CPB_NM']==gu
target2 = target[same_gu]
target2

# target2.dtypes

target3=target2.dropna(subset=["FACI_POINT_X"])
target4=target3.dropna(subset=["FACI_POINT_Y"])


target4

# target5=target4.dropna(subset=["FMNG_USER_TEL"])
# Out:
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 298         정상운영  서울특별시     중구    126.991127     37.560088           NaN
# 326         정상운영  서울특별시     중구    127.016534     37.564217           NaN
# 327         정상운영  서울특별시     중구    126.973561     37.559473           NaN
# 528         정상운영  서울특별시     중구    126.985168     37.562531           NaN
# 529         정상운영  서울특별시     중구    126.985168     37.562531           NaN
# ...          ...    ...    ...           ...           ...           ...
# 107583      정상운영  서울특별시     중구    126.985128     37.560416           NaN
# 107696      정상운영  서울특별시     중구    127.020981     37.566794  02-2231-5547
# 107712      정상운영  서울특별시     중구    127.015401     37.558988           NaN
# 108213      정상운영  서울특별시     중구    126.986150     37.564903  02-3705-6032
# 108274      정상운영  서울특별시     중구    126.994825     37.561141           NaN
#
#                          FACI_ROAD_ADDR1                        FACI_ADDR1  \
# 298     중구 삼일대로2길 50, 지하2층(예장동, 오리엔스 호텔)  중구 삼일대로2길 50, 지하2층(예장동, 오리엔스 호텔)
# 326             서울 중구 다산로 240, 지하1층(신당동)          서울 중구 다산로 240, 지하1층(신당동)
# 327         중구 칠패로 42, 지하1층(봉래동1가, 우리빌딩)      중구 칠패로 42, 지하1층(봉래동1가, 우리빌딩)
# 528                           중구 명동8길 27                        중구 명동8길 27
# 529               서울특별시 중구 명동8길 27(명동2가)            서울특별시 중구 명동8길 27(명동2가)
# ...                                  ...                               ...
# 107583              서울 중구 남산동1가 5-2번지 1층              서울 중구 남산동1가 5-2번지 1층
# 107696       서울특별시 중구 퇴계로87길 23-29 (황학동)                서울특별시 중구 황학동 395-2
# 107712                  서울 중구 신당동 321-27                  서울 중구 신당동 321-27
# 108213                 서울특별시 중구 명동11길 20                    서울 중구 명동11길 20
# 108274                   서울 중구 필동2가 15-7                   서울 중구 필동2가 15-7
#
#              거리
# 298     0.00924
# 326     0.01740
# 327     0.02665
# 528     0.01561
# 529     0.01561
# ...         ...
# 107583  0.01521
# 107696  0.02248
# 107712  0.01523
# 108213  0.01553
# 108274  0.00609
#
# [379 rows x 9 columns]

# %%
target4=target4.sort_values(by=['거리'], axis=0)
target4
# Out:
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 78216       정상운영  서울특별시     중구    127.001326     37.559970  02-3396-4685
# 88109        NaN  서울특별시     중구    127.002304     37.560150  02-2270-3243
# 104912      정상운영  서울특별시     중구    126.998474     37.560946           NaN
# 11032       정상운영  서울특별시     중구    127.000299     37.561494           NaN
# 30745       정상운영  서울특별시     중구    126.997320     37.560189           NaN
# ...          ...    ...    ...           ...           ...           ...
# 45864       정상운영  서울특별시     중구    126.965304     37.558116           NaN
# 105163      정상운영  서울특별시     중구    126.965304     37.558116           NaN
# 38721       정상운영  서울특별시     중구    126.965251     37.556411           NaN
# 3150        정상운영  서울특별시     중구    126.964489     37.559521   02-392-1220
# 104765      정상운영  서울특별시     중구    127.418421     36.318993           NaN
#
#                               FACI_ROAD_ADDR1  \
# 78216              서울특별시 중구 퇴계로50길 59 (장충동2가)
# 88109                        서울특별시 중구 동호로 287
# 104912                     서울 중구 필동3가 18-3 4층
# 11032                          서울 중구 묵정동 29-6
# 30745                    서울 중구 필동3가 21-7 지하2층
# ...                                       ...
# 45864          서울 중구 중림동 200 삼성싸이버빌리지 상가 205동
# 105163  서울특별시 중구 중림로 10 (중림동, 중림동 삼성 사이버 빌리지)
# 38721                        서울특별시 중구 손기정로 73
# 3150                            서울 중구 중림동 610
# 104765                       중구 충무로 15(충무로3가)
#
#                              FACI_ADDR1       거리
# 78216                               NaN  0.00206
# 88109                     서울 중구 동호로 287  0.00284
# 104912                  서울 중구 필동3가 18-3  0.00319
# 11032                    서울 중구 묵정동 29-6  0.00324
# 30745              서울 중구 필동3가 21-7 지하2층  0.00346
# ...                                 ...      ...
# 45864                     서울 중구 중림동 200  0.03488
# 105163  서울특별시 중구 중림동 200 중림동 삼성 사이버 빌리지  0.03488
# 38721                     서울 중구 손기정로 73  0.03498
# 3150                      서울 중구 중림동 610  0.03572
# 104765                 중구 충무로 15(충무로3가)  1.30794
#
# [379 rows x 9 columns]

# %%
print (target4.loc[target4['거리'] == target4["거리"].iloc[0]])
print (target4.loc[target4['거리'] == target4["거리"].iloc[1]])
print (target4.loc[target4['거리'] == target4["거리"].iloc[2]])
# Out:
#       FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 78216      정상운영  서울특별시     중구    127.001326      37.55997  02-3396-4685
#
#                   FACI_ROAD_ADDR1 FACI_ADDR1       거리
# 78216  서울특별시 중구 퇴계로50길 59 (장충동2가)        NaN  0.00206
#       FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 88109       NaN  서울특별시     중구    127.002304      37.56015  02-2270-3243
#
#         FACI_ROAD_ADDR1     FACI_ADDR1       거리
# 88109  서울특별시 중구 동호로 287  서울 중구 동호로 287  0.00284
#        FACI_STAT  CP_NM CPB_NM  FACI_POINT_X  FACI_POINT_Y FMNG_USER_TEL  \
# 104912      정상운영  서울특별시     중구    126.998474     37.560946           NaN
#
#            FACI_ROAD_ADDR1       FACI_ADDR1       거리
# 104912  서울 중구 필동3가 18-3 4층  서울 중구 필동3가 18-3  0.00319

# %%
y1=target4.loc[target4['거리'] == target4["거리"].iloc[0]]
y2 = target4.loc[target4['거리'] == target4["거리"].iloc[1]]
y3 = target4.loc[target4['거리'] == target4["거리"].iloc[2]]

y1_1 = y1.values.tolist()
y2_1 = y2.values.tolist()
y3_1 = y3.values.tolist()


print("person1의 사용자 기록 위치와 가까운 시설을 안내합니다.")
print("1순위 : ",y1_1[0][6],y1_1[0][7],y1_1[0][5])
print("2순위 : ",y2_1[0][6],y2_1[0][7],y2_1[0][5])
print("3순위 : ",y3_1[0][6],y3_1[0][7],y3_1[0][5])
# Out:
# person1의 사용자 기록 위치와 가까운 시설을 안내합니다.
# 1순위 :  서울특별시 중구 퇴계로50길 59 (장충동2가) nan 02-3396-4685
# 2순위 :  서울특별시 중구 동호로 287 서울 중구 동호로 287 02-2270-3243
# 3순위 :  서울 중구 필동3가 18-3 4층 서울 중구 필동3가 18-3 nan
